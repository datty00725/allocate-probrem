# %%
# %run ./CFLP_Cplex.ipynb

# %%
# 需要点と施設候補の座標データ
demand_points = [(1, 1), (2, 2), (3, 3)]
candidate_sites = [(10, 10), (20, 20), (30, 30)]

J = len(candidate_sites)  # 施設候補の数
D = len(demand_points)  # 需要点の数
alpha = 0.2
beta = 0.2

p = 1
r = 1

h_i = np.full(D, 1 / D)

# 既存のリーダーの施設セット J_L を仮定
J_L = {}  # インデックスとして候補施設の一部を選択
J_F = {}

# %%
distances = compute_distances(demand_points, candidate_sites)

# w_ij の計算
wij_matrix = np.exp(alpha - beta * distances)


# U_i^L の計算
Ui_L = compute_Ui_L(wij_matrix, J_L)

# U_i^F の計算
Ui_F = compute_Ui_F(wij_matrix, J_F)

# %%
# グローバル変数を定義
F = []  # 問題のセット
BestSol = None  # 最良解
theta_LB = 0  # 下限値

# %% [markdown]
# # compute_distancesの検証

# %%
# ====== テストの実行 ======
print("🔍 [Test 1] 基本的なケース")
demand_points = [(0, 0), (1, 1)]
candidate_sites = [(1, 0), (2, 2)]
expected = np.array([
    [1.0, np.sqrt(8)],  # (0,0) → (1,0) = 1, (0,0) → (2,2) = sqrt(8)
    [1.0, np.sqrt(2)]    # (1,1) → (1,0) = 1, (1,1) → (2,2) = sqrt(2)
])
result = compute_distances(demand_points, candidate_sites)

if np.allclose(result, expected):
    print("✅ Test 1 Passed!")
else:
    print(f"❌ Test 1 Failed! \nExpected:\n{expected}\nGot:\n{result}")

print("\n🔍 [Test 2] ゼロ距離チェック")
demand_points = [(2, 2)]
candidate_sites = [(2, 2)]
expected = np.array([[0.0]])  # 同じ座標なので距離は0
result = compute_distances(demand_points, candidate_sites)

if np.allclose(result, expected):
    print("✅ Test 2 Passed!")
else:
    print(f"❌ Test 2 Failed! \nExpected:\n{expected}\nGot:\n{result}")

print("\n🔍 [Test 3] 対称性チェック")
demand_points = [(1, 0)]
candidate_sites = [(0, 0), (2, 0)]
expected = np.array([[1.0, 1.0]])  # (1,0) → (0,0) = 1, (1,0) → (2,0) = 1
result = compute_distances(demand_points, candidate_sites)

if np.allclose(result, expected):
    print("✅ Test 3 Passed!")
else:
    print(f"❌ Test 3 Failed! \nExpected:\n{expected}\nGot:\n{result}")

print("\n🔍 [Test 4] 大きな値のチェック")
demand_points = [(1000, 2000)]
candidate_sites = [(3000, 4000)]
expected = np.array([[np.sqrt(8000000)]])  # sqrt((3000-1000)^2 + (4000-2000)^2)
result = compute_distances(demand_points, candidate_sites)

if np.allclose(result, expected):
    print("✅ Test 4 Passed!")
else:
    print(f"❌ Test 4 Failed! \nExpected:\n{expected}\nGot:\n{result}")
# Out:
# 🔍 [Test 1] 基本的なケース
# ✅ Test 1 Passed!
#
# 🔍 [Test 2] ゼロ距離チェック
# ✅ Test 2 Passed!
#
# 🔍 [Test 3] 対称性チェック
# ✅ Test 3 Passed!
#
# 🔍 [Test 4] 大きな値のチェック
# ✅ Test 4 Passed!

# %%
solve_s_cflp()
# Out:
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 1 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.00 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.00 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 2 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.00 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.00 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 3 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.00 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.00 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 4 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 5 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 6 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.02 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.02 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.02 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 7 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.00 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 8 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 9 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 10 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 11 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.01 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.01 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
# ...
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 46 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.03 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.03 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 47 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.03 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.03 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 48 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.03 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.03 ticks)
#
# 🔍 [DEBUG] in add_cuts | Y (フォロワーの施設集合): {1}
# 📌 [DEBUG] J_set (リーダーの候補施設集合): {0, 1, 2}
#
# 🔄 [DEBUG] Checking subset S: set()
#    L_Y(S_set, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.8326
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=inf)
#
# 🔄 [DEBUG] Checking subset S: {0}
#    L_Y(S_set, Y): 2.8326
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8326
#    ✅ [UPDATE] New Best S Found! (cut_value=2.8326 <= min_cut_value=2.8326)
#
# 🔄 [DEBUG] Checking subset S: {1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {2}
#    L_Y(S_set, Y): 0.1674
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 2.6657
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=2, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 2}
#    L_Y(S_set, Y): 2.8331
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=1, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#       k=0, rho_Y(S, k, Y) * x_hat[k]: 0.0000
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# 🔄 [DEBUG] Checking subset S: {0, 1, 2}
#    L_Y(S_set, Y): 3.0000
#    Σ rho_Y(J\k, k, Y) (定数項補正):
#       k=0, rho_Y(J\0, k, Y): 0.0000
#       k=1, rho_Y(J\1, k, Y): 0.1669
#       k=2, rho_Y(J\2, k, Y): 0.0000
#    Σ rho_Y(J\k, k, Y) * x_hat[k]:
#       k=0, rho_Y(J\0, k, Y) * x_hat[k]: 0.0000
#       k=1, rho_Y(J\1, k, Y) * x_hat[k]: 0.0000
#       k=2, rho_Y(J\2, k, Y) * x_hat[k]: 0.0000
#    Σ rho_Y(S, k, Y) * x_hat[k]:
#    ➡️ Computed cut_value: 2.8331
#    ❌ [NO UPDATE] cut_value=2.8331 > min_cut_value=2.8326
#
# === ✅ Best S Found ===
#    S* = [0] (最も違反する部分集合)
# ====================
#
#
# === ➕ Added Submodular Cut ===
#    -θ + (0.0000)x_0 + (0.1674)x_1 + (0.0006)x_2 ≥ 2.8326
# ==============================
#
# 0
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# 2 of 2 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 1.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 49 rows and 4 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.02 sec. (0.03 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.02 sec. (0.03 ticks)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 solve_s_cflp()
#
# File ~\AppData\Local\Temp\ipykernel_5024\1426665718.py:13, in solve_s_cflp()
#      11 problem = F.pop()
#      12 # **連続緩和問題を解く**
# ---> 13 incumbent_solution = solve_relaxation(problem)
#      15 # **分離問題を解く**
#      16 y_star = separation_problem(incumbent_solution)
#
# File ~\AppData\Local\Temp\ipykernel_5024\2784862820.py:13, in solve_relaxation(problem)
#       2 """
#       3 連続緩和問題を解き、インカンベント解 (x_hat, theta_hat) を取得する。
#       4
#    (...)
#       9     dict: インカンベント解 {'x': np.array, 'theta': float}
#      10 """
#      12 # 問題を解く
# ---> 13 problem.solve()
#      15 # CPLEX の解の取得（変数名のアンダースコアを削除）
#      16 x_values = np.array(
#      17     problem.solution.get_values([f"x{j}" for j in range(J)])
#      18 )  # "x_0" → "x0"
#
# File c:\Users\adach\anaconda3\lib\site-packages\cplex\__init__.py:1304, in Cplex.solve(self, paramsets)
#    1300     _proc.multiobjopt(self._env._e, self._lp,
#    1301                       [None if ps is None else ps._ps
#    1302                        for ps in paramsets])
#    1303 elif self._is_MIP():
# -> 1304     _proc.mipopt(self._env._e, self._lp)
#    1305 elif self.quadratic_constraints.get_num() > 0:
#    1306     lpmethod = self.parameters.lpmethod.get()
#
# File c:\Users\adach\anaconda3\lib\site-packages\cplex\_internal\_procedural.py:707, in mipopt(env, lp)
#     705 def mipopt(env, lp):
#     706     with SigIntHandler():
# --> 707         status = CR.CPXXmipopt(env, lp)
#     708     check_status(env, status)
#
# File c:\Users\adach\anaconda3\lib\site-packages\cplex\_internal\_pycplex.py:1536, in CPXXmipopt(env, lp)
#    1535 def CPXXmipopt(env: 'CPXCENVptr', lp: 'CPXLPptr') -> "int":
# -> 1536     return _pycplex_platform.CPXXmipopt(env, lp)
#
# KeyboardInterrupt:
