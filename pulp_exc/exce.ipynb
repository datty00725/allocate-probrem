# %%
import numpy as np
from scflp_v2 import SCFLPData, SCFLPSolver, make_random_instance

# %%
I = 60
J = 60
p = 2
r = 2
beta = 0.1

# %%
seed = np.random.SeedSequence()
# 1) Build a toy instance (no pre-existing facilities)
data = make_random_instance(I=I, J=J, p=p, r=r, beta=beta, seed=seed)

# 2) Solve (PuLP/CBC by default). If you have Gurobi, use milp_backend='gurobi'
solver = SCFLPSolver(data, milp_backend="pulp", pulp_solver="CBC")
result = solver.solve(max_rounds=2000, verbose=True)
# Out:
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 60, 需要点 I = 60, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 6]（r = 2）。上界 α − βᵀŷ = 0.747450
# ➤ 📐 評価：L(x̂,ŷ) = 0.415102 → 違反量 \hat(θ) - L = 5.849e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [25, 57]（r = 2）。上界 α − βᵀŷ = 0.775564
# ➤ 📐 評価：L(x̂,ŷ) = 0.557500 → 違反量 \hat(θ) - L = 4.425e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.796821, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.764092
# ➤ 📐 評価：L(x̂,ŷ) = 0.575099 → 違反量 \hat(θ) - L = 2.217e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.796821, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [6, 40]（r = 2）。上界 α − βᵀŷ = 0.759610
# ➤ 📐 評価：L(x̂,ŷ) = 0.508441 → 違反量 \hat(θ) - L = 2.884e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.760680, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 57]（r = 2）。上界 α − βᵀŷ = 0.773592
# ➤ 📐 評価：L(x̂,ŷ) = 0.538958 → 違反量 \hat(θ) - L = 2.217e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.628531, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.719824
# ➤ 📐 評価：L(x̂,ŷ) = 0.542313 → 違反量 \hat(θ) - L = 8.622e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.621124, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [6, 54]（r = 2）。上界 α − βᵀŷ = 0.754602
# ➤ 📐 評価：L(x̂,ŷ) = 0.545679 → 違反量 \hat(θ) - L = 7.545e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.612261, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.732780
# ➤ 📐 評価：L(x̂,ŷ) = 0.565066 → 違反量 \hat(θ) - L = 4.719e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.588334, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.738585
# ➤ 📐 評価：L(x̂,ŷ) = 0.575634 → 違反量 \hat(θ) - L = 1.270e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.585355, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.747296
# ➤ 📐 評価：L(x̂,ŷ) = 0.580647 → 違反量 \hat(θ) - L = 4.708e-03
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.582385, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [25, 57]（r = 2）。上界 α − βᵀŷ = 0.769250
# ➤ 📐 評価：L(x̂,ŷ) = 0.549947 → 違反量 \hat(θ) - L = 3.244e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 12: master 解 → \hat(θ) = 0.580647, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.747296
# ➤ 📐 評価：L(x̂,ŷ) = 0.580647 → 違反量 \hat(θ) - L = -2.389e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 1.61s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.580647 / 選択サイト [6, 12]
# ➤ 🧷 反復 12 回・追加カット 22 本・合計時間 1.61s

# %%
print("\n=== RESULT ===")
x = result["x"]
print("Objective (leader market share):", result["obj"])
print("Selected sites (indices where x=1):", np.where(x > 0.5)[0].tolist())
print(
    "theta:",
    result["theta"],
    "sum x:",
    x.sum(),
    "iterations:",
    result["iterations"],
    "cuts:",
    result["cuts"],
)
# Out:
# === RESULT ===
# Objective (leader market share): 0.58064715
# Selected sites (indices where x=1): [6, 12]
# theta: 0.58064715 sum x: 2.0 iterations: 12 cuts: 22

# %% [markdown]
# ## 10回回して平均取る

# %%
import numpy as np

I, J, p, r, beta = 10, 10, 2, 2, 0.1  # 例: パラメータ
n_runs = 10
results = []

for run in range(n_runs):
    seed = np.random.SeedSequence()  # 各回ごとに新しい乱数シード
    data = make_random_instance(I=I, J=J, p=p, r=r, beta=beta, seed=seed)

    solver = SCFLPSolver(data, milp_backend="pulp", pulp_solver="CBC")
    result = solver.solve(max_rounds=2000, verbose=False)  # verboseを抑制
    results.append(result)

# --- 平均をとる ---
# resultが辞書形式を仮定し、数値部分を平均化
from collections import defaultdict

averages = defaultdict(float)
for res in results:
    for k, v in res.items():
        if isinstance(v, (int, float)):  # 数値のみ対象
            averages[k] += v / n_runs

print("平均結果:")
for k, v in averages.items():
    print(f"{k}: {v}")
# Out:
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.615497
# ➤ 📐 評価：L(x̂,ŷ) = 0.481040 → 違反量 \hat(θ) - L = 5.190e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 2]（r = 2）。上界 α − βᵀŷ = 0.653631
# ➤ 📐 評価：L(x̂,ŷ) = 0.478742 → 違反量 \hat(θ) - L = 5.213e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.768923, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.656509
# ➤ 📐 評価：L(x̂,ŷ) = 0.548424 → 違反量 \hat(θ) - L = 2.205e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.768923, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 5]（r = 2）。上界 α − βᵀŷ = 0.590373
# ➤ 📐 評価：L(x̂,ŷ) = 0.510680 → 違反量 \hat(θ) - L = 2.582e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.709819, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.651304
# ➤ 📐 評価：L(x̂,ŷ) = 0.489320 → 違反量 \hat(θ) - L = 2.205e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.688835, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 5]（r = 2）。上界 α − βᵀŷ = 0.622656
# ➤ 📐 評価：L(x̂,ŷ) = 0.451576 → 違反量 \hat(θ) - L = 2.373e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.578969, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.657312
# ➤ 📐 評価：L(x̂,ŷ) = 0.529169 → 違反量 \hat(θ) - L = 4.980e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.575725, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.621545
# ➤ 📐 評価：L(x̂,ŷ) = 0.521258 → 違反量 \hat(θ) - L = 5.447e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.548424, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.656509
# ➤ 📐 評価：L(x̂,ŷ) = 0.548424 → 違反量 \hat(θ) - L = 4.006e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.72s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.548424 / 選択サイト [2, 5]
# ➤ 🧷 反復 9 回・追加カット 16 本・合計時間 0.72s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 6]（r = 2）。上界 α − βᵀŷ = 0.582445
# ➤ 📐 評価：L(x̂,ŷ) = 0.382575 → 違反量 \hat(θ) - L = 6.174e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.612330
# ➤ 📐 評価：L(x̂,ŷ) = 0.532028 → 違反量 \hat(θ) - L = 4.680e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.772088, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.647219
# ➤ 📐 評価：L(x̂,ŷ) = 0.500597 → 違反量 \hat(θ) - L = 2.715e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.772088, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 6]（r = 2）。上界 α − βᵀŷ = 0.643065
# ➤ 📐 評価：L(x̂,ŷ) = 0.511551 → 違反量 \hat(θ) - L = 2.605e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.739462, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 6]（r = 2）。上界 α − βᵀŷ = 0.623691
# ➤ 📐 評価：L(x̂,ŷ) = 0.499403 → 違反量 \hat(θ) - L = 2.401e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.728509, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 5]（r = 2）。上界 α − βᵀŷ = 0.627278
# ➤ 📐 評価：L(x̂,ŷ) = 0.488449 → 違反量 \hat(θ) - L = 2.401e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.621428, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 6]（r = 2）。上界 α − βᵀŷ = 0.586746
# ➤ 📐 評価：L(x̂,ŷ) = 0.467972 → 違反量 \hat(θ) - L = 1.535e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.532028, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.612330
# ➤ 📐 評価：L(x̂,ŷ) = 0.532028 → 違反量 \hat(θ) - L = -3.333e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.52s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.532028 / 選択サイト [5, 6]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.52s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 9]（r = 2）。上界 α − βᵀŷ = 0.468924
# ➤ 📐 評価：L(x̂,ŷ) = 0.381469 → 違反量 \hat(θ) - L = 6.185e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.698849
# ➤ 📐 評価：L(x̂,ŷ) = 0.559816 → 違反量 \hat(θ) - L = 4.402e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.770888, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 2]（r = 2）。上界 α − βᵀŷ = 0.657172
# ➤ 📐 評価：L(x̂,ŷ) = 0.507571 → 違反量 \hat(θ) - L = 2.633e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.770888, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 9]（r = 2）。上界 α − βᵀŷ = 0.633715
# ➤ 📐 評価：L(x̂,ŷ) = 0.474388 → 違反量 \hat(θ) - L = 2.965e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.712940, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.603454
# ➤ 📐 評価：L(x̂,ŷ) = 0.525612 → 違反量 \hat(θ) - L = 1.873e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.668529, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 9]（r = 2）。上界 α − βᵀŷ = 0.577478
# ➤ 📐 評価：L(x̂,ŷ) = 0.492429 → 違反量 \hat(θ) - L = 1.761e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.584670, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.608291
# ➤ 📐 評価：L(x̂,ŷ) = 0.481024 → 違反量 \hat(θ) - L = 1.036e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.564670, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.615113
# ➤ 📐 評価：L(x̂,ŷ) = 0.523217 → 違反量 \hat(θ) - L = 4.145e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.563261, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 9]（r = 2）。上界 α − βᵀŷ = 0.585123
# ➤ 📐 評価：L(x̂,ŷ) = 0.458549 → 違反量 \hat(θ) - L = 1.047e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.563261, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 9]（r = 2）。上界 α − βᵀŷ = 0.520289
# ➤ 📐 評価：L(x̂,ŷ) = 0.446603 → 違反量 \hat(θ) - L = 1.167e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.559816, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.698849
# ➤ 📐 評価：L(x̂,ŷ) = 0.559816 → 違反量 \hat(θ) - L = 3.886e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.82s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.559816 / 選択サイト [2, 9]
# ➤ 🧷 反復 11 回・追加カット 20 本・合計時間 0.82s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.628452
# ➤ 📐 評価：L(x̂,ŷ) = 0.507592 → 違反量 \hat(θ) - L = 4.924e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 1]（r = 2）。上界 α − βᵀŷ = 0.629661
# ➤ 📐 評価：L(x̂,ŷ) = 0.492408 → 違反量 \hat(θ) - L = 5.076e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.763562, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.631995
# ➤ 📐 評価：L(x̂,ŷ) = 0.531164 → 違反量 \hat(θ) - L = 2.324e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.744030, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 2]（r = 2）。上界 α − βᵀŷ = 0.626470
# ➤ 📐 評価：L(x̂,ŷ) = 0.511633 → 違反量 \hat(θ) - L = 2.324e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.724806, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 3]（r = 2）。上界 α − βᵀŷ = 0.633661
# ➤ 📐 評価：L(x̂,ŷ) = 0.488367 → 違反量 \hat(θ) - L = 2.364e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.724806, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 2]（r = 2）。上界 α − βᵀŷ = 0.559860
# ➤ 📐 評価：L(x̂,ŷ) = 0.468836 → 違反量 \hat(θ) - L = 2.560e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.636077, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 2]（r = 2）。上界 α − βᵀŷ = 0.540925
# ➤ 📐 評価：L(x̂,ŷ) = 0.417744 → 違反量 \hat(θ) - L = 2.183e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.602461, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 2]（r = 2）。上界 α − βᵀŷ = 0.595658
# ➤ 📐 評価：L(x̂,ŷ) = 0.486340 → 違反量 \hat(θ) - L = 1.161e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.595321, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 1]（r = 2）。上界 α − βᵀŷ = 0.612695
# ➤ 📐 評価：L(x̂,ŷ) = 0.497116 → 違反量 \hat(θ) - L = 9.820e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.551473, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 2]（r = 2）。上界 α − βᵀŷ = 0.541340
# ➤ 📐 評価：L(x̂,ŷ) = 0.497714 → 違反量 \hat(θ) - L = 5.376e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.534286, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 2]（r = 2）。上界 α − βᵀŷ = 0.560558
# ➤ 📐 評価：L(x̂,ŷ) = 0.512897 → 違反量 \hat(θ) - L = 2.139e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 12: master 解 → \hat(θ) = 0.531164, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.631995
# ➤ 📐 評価：L(x̂,ŷ) = 0.531164 → 違反量 \hat(θ) - L = -3.822e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.98s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.531164 / 選択サイト [1, 2]
# ➤ 🧷 反復 12 回・追加カット 22 本・合計時間 0.98s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 7]（r = 2）。上界 α − βᵀŷ = 0.513478
# ➤ 📐 評価：L(x̂,ŷ) = 0.317286 → 違反量 \hat(θ) - L = 6.827e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 6]（r = 2）。上界 α − βᵀŷ = 0.671359
# ➤ 📐 評価：L(x̂,ŷ) = 0.545784 → 違反量 \hat(θ) - L = 4.542e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.779087, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 6]（r = 2）。上界 α − βᵀŷ = 0.651559
# ➤ 📐 評価：L(x̂,ŷ) = 0.538915 → 違反量 \hat(θ) - L = 2.402e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.764939, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [6, 7]（r = 2）。上界 α − βᵀŷ = 0.636113
# ➤ 📐 評価：L(x̂,ŷ) = 0.488203 → 違反量 \hat(θ) - L = 2.767e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.752464, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 5]（r = 2）。上界 α − βᵀŷ = 0.655495
# ➤ 📐 評価：L(x̂,ŷ) = 0.523230 → 違反量 \hat(θ) - L = 2.292e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.701752, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 7]（r = 2）。上界 α − βᵀŷ = 0.631558
# ➤ 📐 評価：L(x̂,ŷ) = 0.558740 → 違反量 \hat(θ) - L = 1.430e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.627270, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 7]（r = 2）。上界 α − βᵀŷ = 0.625031
# ➤ 📐 評価：L(x̂,ŷ) = 0.489702 → 違反量 \hat(θ) - L = 1.376e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.558740, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 7]（r = 2）。上界 α − βᵀŷ = 0.631558
# ➤ 📐 評価：L(x̂,ŷ) = 0.558740 → 違反量 \hat(θ) - L = -4.809e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.51s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.558740 / 選択サイト [5, 6]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.51s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 7]（r = 2）。上界 α − βᵀŷ = 0.534177
# ➤ 📐 評価：L(x̂,ŷ) = 0.366182 → 違反量 \hat(θ) - L = 6.338e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 8]（r = 2）。上界 α − βᵀŷ = 0.663148
# ➤ 📐 評価：L(x̂,ŷ) = 0.501591 → 違反量 \hat(θ) - L = 4.984e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.730385, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 8]（r = 2）。上界 α − βᵀŷ = 0.652730
# ➤ 📐 評価：L(x̂,ŷ) = 0.564143 → 違反量 \hat(θ) - L = 1.662e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.721124, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 7]（r = 2）。上界 α − βᵀŷ = 0.647334
# ➤ 📐 評価：L(x̂,ŷ) = 0.504800 → 違反量 \hat(θ) - L = 2.163e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.721124, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.607210
# ➤ 📐 評価：L(x̂,ŷ) = 0.435857 → 違反量 \hat(θ) - L = 2.853e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.635797, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 8]（r = 2）。上界 α − βᵀŷ = 0.598292
# ➤ 📐 評価：L(x̂,ŷ) = 0.495200 → 違反量 \hat(θ) - L = 1.406e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.599882, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 7]（r = 2）。上界 α − βᵀŷ = 0.645465
# ➤ 📐 評価：L(x̂,ŷ) = 0.517468 → 違反量 \hat(θ) - L = 8.241e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.568837, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 8]（r = 2）。上界 α − βᵀŷ = 0.585643
# ➤ 📐 評価：L(x̂,ŷ) = 0.498078 → 違反量 \hat(θ) - L = 7.076e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.564143, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 8]（r = 2）。上界 α − βᵀŷ = 0.652730
# ➤ 📐 評価：L(x̂,ŷ) = 0.564143 → 違反量 \hat(θ) - L = -2.887e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.67s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.564143 / 選択サイト [1, 4]
# ➤ 🧷 反復 9 回・追加カット 16 本・合計時間 0.67s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 8]（r = 2）。上界 α − βᵀŷ = 0.525492
# ➤ 📐 評価：L(x̂,ŷ) = 0.403016 → 違反量 \hat(θ) - L = 5.970e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 4]（r = 2）。上界 α − βᵀŷ = 0.614896
# ➤ 📐 評価：L(x̂,ŷ) = 0.504380 → 違反量 \hat(θ) - L = 4.956e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.766373, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 8]（r = 2）。上界 α − βᵀŷ = 0.594415
# ➤ 📐 評価：L(x̂,ŷ) = 0.543534 → 違反量 \hat(θ) - L = 2.228e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.766373, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 4]（r = 2）。上界 α − βᵀŷ = 0.577827
# ➤ 📐 評価：L(x̂,ŷ) = 0.484831 → 違反量 \hat(θ) - L = 2.815e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.738008, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 8]（r = 2）。上界 α − βᵀŷ = 0.613153
# ➤ 📐 評価：L(x̂,ŷ) = 0.515169 → 違反量 \hat(θ) - L = 2.228e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.718458, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.577039
# ➤ 📐 評価：L(x̂,ŷ) = 0.456466 → 違反量 \hat(θ) - L = 2.620e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.552611, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 8]（r = 2）。上界 α − βᵀŷ = 0.574256
# ➤ 📐 評価：L(x̂,ŷ) = 0.495620 → 違反量 \hat(θ) - L = 5.699e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.543534, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 8]（r = 2）。上界 α − βᵀŷ = 0.594415
# ➤ 📐 評価：L(x̂,ŷ) = 0.543534 → 違反量 \hat(θ) - L = -1.344e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.50s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.543534 / 選択サイト [2, 3]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.50s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 9]（r = 2）。上界 α − βᵀŷ = 0.607188
# ➤ 📐 評価：L(x̂,ŷ) = 0.524756 → 違反量 \hat(θ) - L = 4.752e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 1]（r = 2）。上界 α − βᵀŷ = 0.631080
# ➤ 📐 評価：L(x̂,ŷ) = 0.475244 → 違反量 \hat(θ) - L = 5.248e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.769420, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 9]（r = 2）。上界 α − βᵀŷ = 0.675977
# ➤ 📐 評価：L(x̂,ŷ) = 0.545462 → 違反量 \hat(θ) - L = 2.240e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.748714, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 2]（r = 2）。上界 α − βᵀŷ = 0.663176
# ➤ 📐 評価：L(x̂,ŷ) = 0.518134 → 違反量 \hat(θ) - L = 2.306e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.705824, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 2]（r = 2）。上界 α − βᵀŷ = 0.610075
# ➤ 📐 評価：L(x̂,ŷ) = 0.454538 → 違反量 \hat(θ) - L = 2.513e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.705824, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 9]（r = 2）。上界 α − βᵀŷ = 0.620678
# ➤ 📐 評価：L(x̂,ŷ) = 0.481866 → 違反量 \hat(θ) - L = 2.240e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.545462, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 9]（r = 2）。上界 α − βᵀŷ = 0.675977
# ➤ 📐 評価：L(x̂,ŷ) = 0.545462 → 違反量 \hat(θ) - L = 2.129e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.39s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.545462 / 選択サイト [0, 2]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.39s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 6]（r = 2）。上界 α − βᵀŷ = 0.425930
# ➤ 📐 評価：L(x̂,ŷ) = 0.302854 → 違反量 \hat(θ) - L = 6.971e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.650572
# ➤ 📐 評価：L(x̂,ŷ) = 0.565782 → 違反量 \hat(θ) - L = 4.342e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.822926, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.638906
# ➤ 📐 評価：L(x̂,ŷ) = 0.540831 → 違反量 \hat(θ) - L = 2.821e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.822926, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 6]（r = 2）。上界 α − βᵀŷ = 0.635345
# ➤ 📐 評価：L(x̂,ŷ) = 0.539238 → 違反量 \hat(θ) - L = 2.837e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.717906, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 9]（r = 2）。上界 α − βᵀŷ = 0.502620
# ➤ 📐 評価：L(x̂,ŷ) = 0.460762 → 違反量 \hat(θ) - L = 2.571e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.704123, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [6, 9]（r = 2）。上界 α − βᵀŷ = 0.505416
# ➤ 📐 評価：L(x̂,ŷ) = 0.459169 → 違反量 \hat(θ) - L = 2.450e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.576018, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 6]（r = 2）。上界 α − βᵀŷ = 0.481161
# ➤ 📐 評価：L(x̂,ŷ) = 0.434218 → 違反量 \hat(θ) - L = 1.418e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.565782, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.650572
# ➤ 📐 評価：L(x̂,ŷ) = 0.565782 → 違反量 \hat(θ) - L = 1.965e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.51s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.565782 / 選択サイト [3, 6]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.51s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 9]（r = 2）。上界 α − βᵀŷ = 0.658755
# ➤ 📐 評価：L(x̂,ŷ) = 0.476276 → 違反量 \hat(θ) - L = 5.237e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 3]（r = 2）。上界 α − βᵀŷ = 0.680858
# ➤ 📐 評価：L(x̂,ŷ) = 0.514358 → 違反量 \hat(θ) - L = 4.856e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.779519, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 8]（r = 2）。上界 α − βᵀŷ = 0.641358
# ➤ 📐 評価：L(x̂,ŷ) = 0.478209 → 違反量 \hat(θ) - L = 3.013e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.779519, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 9]（r = 2）。上界 α − βᵀŷ = 0.661630
# ➤ 📐 評価：L(x̂,ŷ) = 0.566472 → 違反量 \hat(θ) - L = 2.130e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.734839, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 9]（r = 2）。上界 α − βᵀŷ = 0.657366
# ➤ 📐 評価：L(x̂,ŷ) = 0.521791 → 違反量 \hat(θ) - L = 2.130e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.698689, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 8]（r = 2）。上界 α − βᵀŷ = 0.627008
# ➤ 📐 評価：L(x̂,ŷ) = 0.433528 → 違反量 \hat(θ) - L = 2.652e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.581130, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 9]（r = 2）。上界 α − βᵀŷ = 0.619266
# ➤ 📐 評価：L(x̂,ŷ) = 0.418025 → 違反量 \hat(θ) - L = 1.631e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.581020, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 9]（r = 2）。上界 α − βᵀŷ = 0.638608
# ➤ 📐 評価：L(x̂,ŷ) = 0.485642 → 違反量 \hat(θ) - L = 9.538e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.574266, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 9]（r = 2）。上界 α − βᵀŷ = 0.659065
# ➤ 📐 評価：L(x̂,ŷ) = 0.562912 → 違反量 \hat(θ) - L = 1.135e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.566472, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 9]（r = 2）。上界 α − βᵀŷ = 0.661630
# ➤ 📐 評価：L(x̂,ŷ) = 0.566472 → 違反量 \hat(θ) - L = 3.963e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.71s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.566472 / 選択サイト [3, 8]
# ➤ 🧷 反復 10 回・追加カット 18 本・合計時間 0.71s
# 平均結果:
# theta: 0.5515566789999999
# obj: 0.5515566789999999
# status: 0.9999999999999999
# iterations: 9.0
# cuts: 16.0
# time_sec: 0.632187008857727

# %% [markdown]
# ## それぞれのインスタンスを平均してCSVに保存

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

# パラメータの候補
instances = [
    {"I": 10, "J": 10, "p": 2, "r": 2, "beta": 0.1},
    {"I": 20, "J": 20, "p": 2, "r": 2, "beta": 0.1},
    {"I": 30, "J": 30, "p": 2, "r": 2, "beta": 0.1},
]

n_runs = 10
all_results = []

for inst_id, params in enumerate(instances, start=1):
    run_results = []
    for run in range(n_runs):
        seed = np.random.SeedSequence()
        data = make_random_instance(**params, seed=seed)
        
        solver = SCFLPSolver(data, milp_backend="pulp", pulp_solver="CBC")
        result = solver.solve(max_rounds=2000, verbose=False)
        
        run_results.append(result)

    # --- インスタンスごとに平均を計算 ---
    avg_theta = np.mean([res["theta"] for res in run_results])
    avg_time = np.mean([res["time_sec"] for res in run_results])

    row = {
        "I": params["I"],
        "J": params["J"],
        "p": params["p"],
        "r": params["r"],
        "beta": params["beta"],
        "theta": avg_theta,
        "time_sec": avg_time
    }
    all_results.append(row)

# --- DataFrameにまとめてCSV保存 ---
df = pd.DataFrame(all_results)
df.to_csv("scflp_results_avg.csv", index=False, encoding="utf-8")

print("保存完了: scflp_results_avg.csv")
# Out:
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 4]（r = 2）。上界 α − βᵀŷ = 0.654566
# ➤ 📐 評価：L(x̂,ŷ) = 0.478919 → 違反量 \hat(θ) - L = 5.211e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 7]（r = 2）。上界 α − βᵀŷ = 0.666202
# ➤ 📐 評価：L(x̂,ŷ) = 0.536216 → 違反量 \hat(θ) - L = 4.638e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.775234, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.645548
# ➤ 📐 評価：L(x̂,ŷ) = 0.516776 → 違反量 \hat(θ) - L = 2.585e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.772125, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 3]（r = 2）。上界 α − βᵀŷ = 0.682010
# ➤ 📐 評価：L(x̂,ŷ) = 0.498441 → 違反量 \hat(θ) - L = 2.737e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.723206, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 7]（r = 2）。上界 α − βᵀŷ = 0.677539
# ➤ 📐 評価：L(x̂,ŷ) = 0.484188 → 違反量 \hat(θ) - L = 2.390e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.652473, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 7]（r = 2）。上界 α − βᵀŷ = 0.611309
# ➤ 📐 評価：L(x̂,ŷ) = 0.466678 → 違反量 \hat(θ) - L = 1.858e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.575607, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 7]（r = 2）。上界 α − βᵀŷ = 0.657988
# ➤ 📐 評価：L(x̂,ŷ) = 0.501838 → 違反量 \hat(θ) - L = 7.377e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.569589, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.640860
# ➤ 📐 評価：L(x̂,ŷ) = 0.488571 → 違反量 \hat(θ) - L = 8.102e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.562065, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.603992
# ➤ 📐 評価：L(x̂,ŷ) = 0.503370 → 違反量 \hat(θ) - L = 5.869e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.536215, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 7]（r = 2）。上界 α − βᵀŷ = 0.666202
# ➤ 📐 評価：L(x̂,ŷ) = 0.536216 → 違反量 \hat(θ) - L = -4.982e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.83s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.536215 / 選択サイト [3, 4]
# ➤ 🧷 反復 10 回・追加カット 18 本・合計時間 0.83s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 6]（r = 2）。上界 α − βᵀŷ = 0.629879
# ➤ 📐 評価：L(x̂,ŷ) = 0.461580 → 違反量 \hat(θ) - L = 5.384e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.652736
# ➤ 📐 評価：L(x̂,ŷ) = 0.525556 → 違反量 \hat(θ) - L = 4.744e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.765973, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.638158
# ➤ 📐 評価：L(x̂,ŷ) = 0.503534 → 違反量 \hat(θ) - L = 2.624e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.765973, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 6]（r = 2）。上界 α − βᵀŷ = 0.660777
# ➤ 📐 評価：L(x̂,ŷ) = 0.502856 → 違反量 \hat(θ) - L = 2.631e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.737561, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 4]（r = 2）。上界 α − βᵀŷ = 0.629243
# ➤ 📐 評価：L(x̂,ŷ) = 0.497144 → 違反量 \hat(θ) - L = 2.404e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.713865, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 6]（r = 2）。上界 α − βᵀŷ = 0.652610
# ➤ 📐 評価：L(x̂,ŷ) = 0.496466 → 違反量 \hat(θ) - L = 2.174e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.541595, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.646651
# ➤ 📐 評価：L(x̂,ŷ) = 0.517270 → 違反量 \hat(θ) - L = 2.433e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.525556, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.652736
# ➤ 📐 評価：L(x̂,ŷ) = 0.525556 → 違反量 \hat(θ) - L = -4.617e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.51s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.525556 / 選択サイト [4, 6]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.51s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 4]（r = 2）。上界 α − βᵀŷ = 0.678170
# ➤ 📐 評価：L(x̂,ŷ) = 0.544950 → 違反量 \hat(θ) - L = 4.551e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 1]（r = 2）。上界 α − βᵀŷ = 0.595524
# ➤ 📐 評価：L(x̂,ŷ) = 0.455050 → 違反量 \hat(θ) - L = 5.449e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.756085, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 3]（r = 2）。上界 α − βᵀŷ = 0.668608
# ➤ 📐 評価：L(x̂,ŷ) = 0.536986 → 違反量 \hat(θ) - L = 2.191e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.756085, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.621318
# ➤ 📐 評価：L(x̂,ŷ) = 0.520135 → 違反量 \hat(θ) - L = 2.360e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.698965, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 3]（r = 2）。上界 α − βᵀŷ = 0.658431
# ➤ 📐 評価：L(x̂,ŷ) = 0.479865 → 違反量 \hat(θ) - L = 2.191e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.698965, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.583370
# ➤ 📐 評価：L(x̂,ŷ) = 0.463014 → 違反量 \hat(θ) - L = 2.360e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.595852, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.543235
# ➤ 📐 評価：L(x̂,ŷ) = 0.419821 → 違反量 \hat(θ) - L = 1.760e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.565614, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.610551
# ➤ 📐 評価：L(x̂,ŷ) = 0.435947 → 違反量 \hat(θ) - L = 1.297e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.547456, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.628878
# ➤ 📐 評価：L(x̂,ŷ) = 0.515457 → 違反量 \hat(θ) - L = 3.200e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.544950, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 4]（r = 2）。上界 α − βᵀŷ = 0.678170
# ➤ 📐 評価：L(x̂,ŷ) = 0.544950 → 違反量 \hat(θ) - L = -2.637e-10
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.77s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.544950 / 選択サイト [0, 1]
# ➤ 🧷 反復 10 回・追加カット 18 本・合計時間 0.77s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.500036
# ➤ 📐 評価：L(x̂,ŷ) = 0.337928 → 違反量 \hat(θ) - L = 6.621e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.667676
# ➤ 📐 評価：L(x̂,ŷ) = 0.530681 → 違反量 \hat(θ) - L = 4.693e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.788815, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 5]（r = 2）。上界 α − βᵀŷ = 0.655689
# ➤ 📐 評価：L(x̂,ŷ) = 0.545239 → 違反量 \hat(θ) - L = 2.436e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.788815, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.639483
# ➤ 📐 評価：L(x̂,ŷ) = 0.588798 → 違反量 \hat(θ) - L = 2.000e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.705616, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 5]（r = 2）。上界 α − βᵀŷ = 0.587021
# ➤ 📐 評価：L(x̂,ŷ) = 0.498290 → 違反量 \hat(θ) - L = 2.073e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.616700, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 4]（r = 2）。上界 α − βᵀŷ = 0.555062
# ➤ 📐 評価：L(x̂,ŷ) = 0.448337 → 違反量 \hat(θ) - L = 1.684e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.588798, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.639483
# ➤ 📐 評価：L(x̂,ŷ) = 0.588798 → 違反量 \hat(θ) - L = -4.623e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.42s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.588798 / 選択サイト [4, 5]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.42s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 8]（r = 2）。上界 α − βᵀŷ = 0.590496
# ➤ 📐 評価：L(x̂,ŷ) = 0.529297 → 違反量 \hat(θ) - L = 4.707e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 1]（r = 2）。上界 α − βᵀŷ = 0.542748
# ➤ 📐 評価：L(x̂,ŷ) = 0.470703 → 違反量 \hat(θ) - L = 5.293e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.761025, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.582219
# ➤ 📐 評価：L(x̂,ŷ) = 0.538799 → 違反量 \hat(θ) - L = 2.222e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.751524, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 8]（r = 2）。上界 α − βᵀŷ = 0.587701
# ➤ 📐 評価：L(x̂,ŷ) = 0.512549 → 違反量 \hat(θ) - L = 2.390e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.709677, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 8]（r = 2）。上界 α − βᵀŷ = 0.560724
# ➤ 📐 評価：L(x̂,ŷ) = 0.461201 → 違反量 \hat(θ) - L = 2.485e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.709677, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.571592
# ➤ 📐 評価：L(x̂,ŷ) = 0.487451 → 違反量 \hat(θ) - L = 2.222e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.538799, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.582219
# ➤ 📐 評価：L(x̂,ŷ) = 0.538799 → 違反量 \hat(θ) - L = 1.485e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.38s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.538799 / 選択サイト [1, 8]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.38s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 4]（r = 2）。上界 α − βᵀŷ = 0.608758
# ➤ 📐 評価：L(x̂,ŷ) = 0.444577 → 違反量 \hat(θ) - L = 5.554e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 6]（r = 2）。上界 α − βᵀŷ = 0.644392
# ➤ 📐 評価：L(x̂,ŷ) = 0.533931 → 違反量 \hat(θ) - L = 4.661e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.793040, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.570687
# ➤ 📐 評価：L(x̂,ŷ) = 0.538772 → 違反量 \hat(θ) - L = 2.543e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.793040, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 2]（r = 2）。上界 α − βᵀŷ = 0.655451
# ➤ 📐 評価：L(x̂,ŷ) = 0.513377 → 違反量 \hat(θ) - L = 2.797e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.737433, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 6]（r = 2）。上界 α − βᵀŷ = 0.613532
# ➤ 📐 評価：L(x̂,ŷ) = 0.486623 → 違反量 \hat(θ) - L = 2.508e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.707144, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 6]（r = 2）。上界 α − βᵀŷ = 0.658018
# ➤ 📐 評価：L(x̂,ŷ) = 0.461228 → 違反量 \hat(θ) - L = 2.459e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.538772, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 4]（r = 2）。上界 α − βᵀŷ = 0.570687
# ➤ 📐 評価：L(x̂,ŷ) = 0.538772 → 違反量 \hat(θ) - L = 4.859e-10
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.41s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.538772 / 選択サイト [2, 6]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.41s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 7]（r = 2）。上界 α − βᵀŷ = 0.557134
# ➤ 📐 評価：L(x̂,ŷ) = 0.418662 → 違反量 \hat(θ) - L = 5.813e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 6]（r = 2）。上界 α − βᵀŷ = 0.675738
# ➤ 📐 評価：L(x̂,ŷ) = 0.562568 → 違反量 \hat(θ) - L = 4.374e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.788053, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 7]（r = 2）。上界 α − βᵀŷ = 0.699145
# ➤ 📐 評価：L(x̂,ŷ) = 0.625747 → 違反量 \hat(θ) - L = 1.623e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.690236, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 2]（r = 2）。上界 α − βᵀŷ = 0.570560
# ➤ 📐 評価：L(x̂,ŷ) = 0.415143 → 違反量 \hat(θ) - L = 2.751e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.637896, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 7]（r = 2）。上界 α − βᵀŷ = 0.638806
# ➤ 📐 評価：L(x̂,ŷ) = 0.533496 → 違反量 \hat(θ) - L = 1.044e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.627495, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 4]（r = 2）。上界 α − βᵀŷ = 0.596516
# ➤ 📐 評価：L(x̂,ŷ) = 0.513669 → 違反量 \hat(θ) - L = 1.138e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.625747, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 7]（r = 2）。上界 α − βᵀŷ = 0.699145
# ➤ 📐 評価：L(x̂,ŷ) = 0.625747 → 違反量 \hat(θ) - L = 3.926e-10
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.49s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.625747 / 選択サイト [0, 2]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.49s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 7]（r = 2）。上界 α − βᵀŷ = 0.293622
# ➤ 📐 評価：L(x̂,ŷ) = 0.202659 → 違反量 \hat(θ) - L = 7.973e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.599164
# ➤ 📐 評価：L(x̂,ŷ) = 0.553134 → 違反量 \hat(θ) - L = 4.469e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.791360, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 7]（r = 2）。上界 α − βᵀŷ = 0.582255
# ➤ 📐 評価：L(x̂,ŷ) = 0.534499 → 違反量 \hat(θ) - L = 2.569e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.783234, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 3]（r = 2）。上界 α − βᵀŷ = 0.542385
# ➤ 📐 評価：L(x̂,ŷ) = 0.495086 → 違反量 \hat(θ) - L = 2.881e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.743139, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 7]（r = 2）。上界 α − βᵀŷ = 0.534040
# ➤ 📐 評価：L(x̂,ŷ) = 0.504914 → 違反量 \hat(θ) - L = 2.382e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.703727, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 5]（r = 2）。上界 α − βᵀŷ = 0.495789
# ➤ 📐 評価：L(x̂,ŷ) = 0.465501 → 違反量 \hat(θ) - L = 2.382e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.583152, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 7]（r = 2）。上界 α − βᵀŷ = 0.476355
# ➤ 📐 評価：L(x̂,ŷ) = 0.446866 → 違反量 \hat(θ) - L = 1.363e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.553134, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.599164
# ➤ 📐 評価：L(x̂,ŷ) = 0.553134 → 違反量 \hat(θ) - L = -2.161e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.47s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.553134 / 選択サイト [2, 7]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.47s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.490621
# ➤ 📐 評価：L(x̂,ŷ) = 0.297183 → 違反量 \hat(θ) - L = 7.028e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 8]（r = 2）。上界 α − βᵀŷ = 0.652649
# ➤ 📐 評価：L(x̂,ŷ) = 0.527400 → 違反量 \hat(θ) - L = 4.726e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.808219, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 9]（r = 2）。上界 α − βᵀŷ = 0.637145
# ➤ 📐 評価：L(x̂,ŷ) = 0.559444 → 違反量 \hat(θ) - L = 2.488e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.779236, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 8]（r = 2）。上界 α − βᵀŷ = 0.613919
# ➤ 📐 評価：L(x̂,ŷ) = 0.536196 → 違反量 \hat(θ) - L = 2.430e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.715881, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 9]（r = 2）。上界 α − βᵀŷ = 0.582300
# ➤ 📐 評価：L(x̂,ŷ) = 0.463804 → 違反量 \hat(θ) - L = 2.521e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.715881, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 5]（r = 2）。上界 α − βᵀŷ = 0.534888
# ➤ 📐 評価：L(x̂,ŷ) = 0.440556 → 違反量 \hat(θ) - L = 2.753e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.590583, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.566298
# ➤ 📐 評価：L(x̂,ŷ) = 0.472600 → 違反量 \hat(θ) - L = 1.180e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.559444, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 9]（r = 2）。上界 α − βᵀŷ = 0.637145
# ➤ 📐 評価：L(x̂,ŷ) = 0.559444 → 違反量 \hat(θ) - L = 1.645e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.48s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.559444 / 選択サイト [3, 5]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.48s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 10, 需要点 I = 10, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 7]（r = 2）。上界 α − βᵀŷ = 0.508213
# ➤ 📐 評価：L(x̂,ŷ) = 0.350907 → 違反量 \hat(θ) - L = 6.491e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 9]（r = 2）。上界 α − βᵀŷ = 0.653939
# ➤ 📐 評価：L(x̂,ŷ) = 0.547466 → 違反量 \hat(θ) - L = 4.525e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.729814, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 9]（r = 2）。上界 α − βᵀŷ = 0.649037
# ➤ 📐 評価：L(x̂,ŷ) = 0.574019 → 違反量 \hat(θ) - L = 1.558e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.722909, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 7]（r = 2）。上界 α − βᵀŷ = 0.593387
# ➤ 📐 評価：L(x̂,ŷ) = 0.472371 → 違反量 \hat(θ) - L = 2.505e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.722909, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 3]（r = 2）。上界 α − βᵀŷ = 0.539312
# ➤ 📐 評価：L(x̂,ŷ) = 0.425981 → 違反量 \hat(θ) - L = 2.969e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.621093, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 9]（r = 2）。上界 α − βᵀŷ = 0.587131
# ➤ 📐 評価：L(x̂,ŷ) = 0.527629 → 違反量 \hat(θ) - L = 9.346e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.574019, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 9]（r = 2）。上界 α − βᵀŷ = 0.649037
# ➤ 📐 評価：L(x̂,ŷ) = 0.574019 → 違反量 \hat(θ) - L = -4.199e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.41s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.574019 / 選択サイト [1, 3]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.41s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 14]（r = 2）。上界 α − βᵀŷ = 0.662044
# ➤ 📐 評価：L(x̂,ŷ) = 0.466693 → 違反量 \hat(θ) - L = 5.333e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 17]（r = 2）。上界 α − βᵀŷ = 0.720387
# ➤ 📐 評価：L(x̂,ŷ) = 0.564698 → 違反量 \hat(θ) - L = 4.353e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.786853, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 13]（r = 2）。上界 α − βᵀŷ = 0.715724
# ➤ 📐 評価：L(x̂,ŷ) = 0.539628 → 違反量 \hat(θ) - L = 2.472e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.786853, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 14]（r = 2）。上界 α − βᵀŷ = 0.683428
# ➤ 📐 評価：L(x̂,ŷ) = 0.505973 → 違反量 \hat(θ) - L = 2.809e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.605820, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 14]（r = 2）。上界 α − βᵀŷ = 0.642083
# ➤ 📐 評価：L(x̂,ŷ) = 0.376304 → 違反量 \hat(θ) - L = 2.295e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.598895, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 17]（r = 2）。上界 α − βᵀŷ = 0.683494
# ➤ 📐 評価：L(x̂,ŷ) = 0.487496 → 違反量 \hat(θ) - L = 1.114e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.589726, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [14, 17]（r = 2）。上界 α − βᵀŷ = 0.673222
# ➤ 📐 評価：L(x̂,ŷ) = 0.466594 → 違反量 \hat(θ) - L = 1.231e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.564698, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 17]（r = 2）。上界 α − βᵀŷ = 0.720387
# ➤ 📐 評価：L(x̂,ŷ) = 0.564698 → 違反量 \hat(θ) - L = -1.026e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.68s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.564698 / 選択サイト [5, 14]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.68s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 13]（r = 2）。上界 α − βᵀŷ = 0.672405
# ➤ 📐 評価：L(x̂,ŷ) = 0.387372 → 違反量 \hat(θ) - L = 6.126e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [15, 16]（r = 2）。上界 α − βᵀŷ = 0.724833
# ➤ 📐 評価：L(x̂,ŷ) = 0.608640 → 違反量 \hat(θ) - L = 3.914e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.805054, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 13]（r = 2）。上界 α − βᵀŷ = 0.657564
# ➤ 📐 評価：L(x̂,ŷ) = 0.550825 → 違反量 \hat(θ) - L = 2.542e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.805054, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.724418
# ➤ 📐 評価：L(x̂,ŷ) = 0.556325 → 違反量 \hat(θ) - L = 2.487e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.655094, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 13]（r = 2）。上界 α − βᵀŷ = 0.603645
# ➤ 📐 評価：L(x̂,ŷ) = 0.399855 → 違反量 \hat(θ) - L = 2.552e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.646335, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 15]（r = 2）。上界 α − βᵀŷ = 0.713156
# ➤ 📐 評価：L(x̂,ŷ) = 0.503894 → 違反量 \hat(θ) - L = 1.424e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.608640, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [15, 16]（r = 2）。上界 α − βᵀŷ = 0.724833
# ➤ 📐 評価：L(x̂,ŷ) = 0.608640 → 違反量 \hat(θ) - L = 4.810e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.59s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.608640 / 選択サイト [4, 13]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.59s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 8]（r = 2）。上界 α − βᵀŷ = 0.595778
# ➤ 📐 評価：L(x̂,ŷ) = 0.385322 → 違反量 \hat(θ) - L = 6.147e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 18]（r = 2）。上界 α − βᵀŷ = 0.699779
# ➤ 📐 評価：L(x̂,ŷ) = 0.516157 → 違反量 \hat(θ) - L = 4.838e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.761543, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 17]（r = 2）。上界 α − βᵀŷ = 0.697590
# ➤ 📐 評価：L(x̂,ŷ) = 0.529727 → 違反量 \hat(θ) - L = 2.318e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.761543, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 17]（r = 2）。上界 α − βᵀŷ = 0.687054
# ➤ 📐 評価：L(x̂,ŷ) = 0.523131 → 違反量 \hat(θ) - L = 2.384e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.633570, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 8]（r = 2）。上界 α − βᵀŷ = 0.668148
# ➤ 📐 評価：L(x̂,ŷ) = 0.517485 → 違反量 \hat(θ) - L = 1.161e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.581855, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 18]（r = 2）。上界 α − βᵀŷ = 0.677746
# ➤ 📐 評価：L(x̂,ŷ) = 0.472115 → 違反量 \hat(θ) - L = 1.097e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.564386, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 18]（r = 2）。上界 α − βᵀŷ = 0.669476
# ➤ 📐 評価：L(x̂,ŷ) = 0.454216 → 違反量 \hat(θ) - L = 1.102e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.531226, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 18]（r = 2）。上界 α − βᵀŷ = 0.698789
# ➤ 📐 評価：L(x̂,ŷ) = 0.486204 → 違反量 \hat(θ) - L = 4.502e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.529727, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 17]（r = 2）。上界 α − βᵀŷ = 0.697590
# ➤ 📐 評価：L(x̂,ŷ) = 0.529727 → 違反量 \hat(θ) - L = -4.856e-10
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.73s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.529727 / 選択サイト [8, 18]
# ➤ 🧷 反復 9 回・追加カット 16 本・合計時間 0.73s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.619262
# ➤ 📐 評価：L(x̂,ŷ) = 0.351213 → 違反量 \hat(θ) - L = 6.488e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 14]（r = 2）。上界 α − βᵀŷ = 0.687442
# ➤ 📐 評価：L(x̂,ŷ) = 0.512599 → 違反量 \hat(θ) - L = 4.874e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.760245, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 14]（r = 2）。上界 α − βᵀŷ = 0.690400
# ➤ 📐 評価：L(x̂,ŷ) = 0.514110 → 違反量 \hat(θ) - L = 2.461e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.760245, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [9, 14]（r = 2）。上界 α − βᵀŷ = 0.676692
# ➤ 📐 評価：L(x̂,ŷ) = 0.493781 → 違反量 \hat(θ) - L = 2.665e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.752354, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 11]（r = 2）。上界 α − βᵀŷ = 0.650342
# ➤ 📐 評価：L(x̂,ŷ) = 0.506219 → 違反量 \hat(θ) - L = 2.461e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.733536, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [9, 11]（r = 2）。上界 α − βᵀŷ = 0.672946
# ➤ 📐 評価：L(x̂,ŷ) = 0.485890 → 違反量 \hat(θ) - L = 2.476e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.552041, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.674478
# ➤ 📐 評価：L(x̂,ŷ) = 0.487401 → 違反量 \hat(θ) - L = 6.464e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.529527, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 11]（r = 2）。上界 α − βᵀŷ = 0.620691
# ➤ 📐 評価：L(x̂,ŷ) = 0.463489 → 違反量 \hat(θ) - L = 6.604e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.528923, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 9]（r = 2）。上界 α − βᵀŷ = 0.651340
# ➤ 📐 評価：L(x̂,ŷ) = 0.459884 → 違反量 \hat(θ) - L = 6.904e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.522215, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [9, 11]（r = 2）。上界 α − βᵀŷ = 0.645104
# ➤ 📐 評価：L(x̂,ŷ) = 0.449945 → 違反量 \hat(θ) - L = 7.227e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.514110, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [5, 14]（r = 2）。上界 α − βᵀŷ = 0.690400
# ➤ 📐 評価：L(x̂,ŷ) = 0.514110 → 違反量 \hat(θ) - L = 3.438e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.97s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.514110 / 選択サイト [9, 11]
# ➤ 🧷 反復 11 回・追加カット 20 本・合計時間 0.97s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 17]（r = 2）。上界 α − βᵀŷ = 0.674142
# ➤ 📐 評価：L(x̂,ŷ) = 0.485944 → 違反量 \hat(θ) - L = 5.141e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 18]（r = 2）。上界 α − βᵀŷ = 0.721879
# ➤ 📐 評価：L(x̂,ŷ) = 0.522176 → 違反量 \hat(θ) - L = 4.778e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.761784, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [16, 17]（r = 2）。上界 α − βᵀŷ = 0.718992
# ➤ 📐 評価：L(x̂,ŷ) = 0.543848 → 違反量 \hat(θ) - L = 2.179e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.761784, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 16]（r = 2）。上界 α − βᵀŷ = 0.722385
# ➤ 📐 評価：L(x̂,ŷ) = 0.543761 → 違反量 \hat(θ) - L = 2.180e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.650313, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 17]（r = 2）。上界 α − βᵀŷ = 0.626405
# ➤ 📐 評価：L(x̂,ŷ) = 0.396777 → 違反量 \hat(θ) - L = 2.535e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.607091, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 18]（r = 2）。上界 α − βᵀŷ = 0.699739
# ➤ 📐 評価：L(x̂,ŷ) = 0.489554 → 違反量 \hat(θ) - L = 1.175e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.607080, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [17, 18]（r = 2）。上界 α − βᵀŷ = 0.699800
# ➤ 📐 評価：L(x̂,ŷ) = 0.481086 → 違反量 \hat(θ) - L = 1.260e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.577777, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 17]（r = 2）。上界 α − βᵀŷ = 0.708623
# ➤ 📐 評価：L(x̂,ŷ) = 0.537040 → 違反量 \hat(θ) - L = 4.074e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.562088, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [17, 18]（r = 2）。上界 α − βᵀŷ = 0.694699
# ➤ 📐 評価：L(x̂,ŷ) = 0.420568 → 違反量 \hat(θ) - L = 1.415e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.560825, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 18]（r = 2）。上界 α − βᵀŷ = 0.692650
# ➤ 📐 評価：L(x̂,ŷ) = 0.418787 → 違反量 \hat(θ) - L = 1.420e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.543848, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [16, 17]（r = 2）。上界 α − βᵀŷ = 0.718992
# ➤ 📐 評価：L(x̂,ŷ) = 0.543848 → 違反量 \hat(θ) - L = 2.638e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 1.12s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.543848 / 選択サイト [2, 18]
# ➤ 🧷 反復 11 回・追加カット 20 本・合計時間 1.12s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [12, 18]（r = 2）。上界 α − βᵀŷ = 0.636979
# ➤ 📐 評価：L(x̂,ŷ) = 0.484152 → 違反量 \hat(θ) - L = 5.158e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 10]（r = 2）。上界 α − βᵀŷ = 0.676214
# ➤ 📐 評価：L(x̂,ŷ) = 0.507693 → 違反量 \hat(θ) - L = 4.923e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.752052, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 18]（r = 2）。上界 α − βᵀŷ = 0.677793
# ➤ 📐 評価：L(x̂,ŷ) = 0.552683 → 違反量 \hat(θ) - L = 1.994e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.732101, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 12]（r = 2）。上界 α − βᵀŷ = 0.674501
# ➤ 📐 評価：L(x̂,ŷ) = 0.495358 → 違反量 \hat(θ) - L = 2.367e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.729826, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 18]（r = 2）。上界 α − βᵀŷ = 0.653484
# ➤ 📐 評価：L(x̂,ŷ) = 0.504642 → 違反量 \hat(θ) - L = 2.252e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.717491, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 12]（r = 2）。上界 α − βᵀŷ = 0.615504
# ➤ 📐 評価：L(x̂,ŷ) = 0.447317 → 違反量 \hat(θ) - L = 2.702e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.571450, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 18]（r = 2）。上界 α − βᵀŷ = 0.603806
# ➤ 📐 評価：L(x̂,ŷ) = 0.441911 → 違反量 \hat(θ) - L = 1.295e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.552683, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [8, 18]（r = 2）。上界 α − βᵀŷ = 0.677793
# ➤ 📐 評価：L(x̂,ŷ) = 0.552683 → 違反量 \hat(θ) - L = -3.724e-10
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.62s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.552683 / 選択サイト [10, 12]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.62s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 16]（r = 2）。上界 α − βᵀŷ = 0.677352
# ➤ 📐 評価：L(x̂,ŷ) = 0.578227 → 違反量 \hat(θ) - L = 4.218e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [9, 11]（r = 2）。上界 α − βᵀŷ = 0.647951
# ➤ 📐 評価：L(x̂,ŷ) = 0.461488 → 違反量 \hat(θ) - L = 5.385e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.739488, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 16]（r = 2）。上界 α − βᵀŷ = 0.716640
# ➤ 📐 評価：L(x̂,ŷ) = 0.533456 → 違反量 \hat(θ) - L = 2.060e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.728997, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [0, 4]（r = 2）。上界 α − βᵀŷ = 0.705774
# ➤ 📐 評価：L(x̂,ŷ) = 0.479511 → 違反量 \hat(θ) - L = 2.495e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.656463, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 16]（r = 2）。上界 α − βᵀŷ = 0.700485
# ➤ 📐 評価：L(x̂,ŷ) = 0.619550 → 違反量 \hat(θ) - L = 3.691e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.640410, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 16]（r = 2）。上界 α − βᵀŷ = 0.700064
# ➤ 📐 評価：L(x̂,ŷ) = 0.622349 → 違反量 \hat(θ) - L = 1.806e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.622349, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [4, 16]（r = 2）。上界 α − βᵀŷ = 0.700064
# ➤ 📐 評価：L(x̂,ŷ) = 0.622349 → 違反量 \hat(θ) - L = 2.197e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.52s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.622349 / 選択サイト [0, 6]
# ➤ 🧷 反復 7 回・追加カット 12 本・合計時間 0.52s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 20, 需要点 I = 20, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [18, 19]（r = 2）。上界 α − βᵀŷ = 0.640255
# ➤ 📐 評価：L(x̂,ŷ) = 0.415709 → 違反量 \hat(θ) - L = 5.843e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 10]（r = 2）。上界 α − βᵀŷ = 0.737484
# ➤ 📐 評価：L(x̂,ŷ) = 0.566574 → 違反量 \hat(θ) - L = 4.334e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.764186, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 18]（r = 2）。上界 α − βᵀŷ = 0.722532
# ➤ 📐 評価：L(x̂,ŷ) = 0.497161 → 違反量 \hat(θ) - L = 2.670e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.764186, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 19]（r = 2）。上界 α − βᵀŷ = 0.682276
# ➤ 📐 評価：L(x̂,ŷ) = 0.464638 → 違反量 \hat(θ) - L = 2.995e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.732975, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 18]（r = 2）。上界 α − βᵀŷ = 0.742531
# ➤ 📐 評価：L(x̂,ŷ) = 0.535362 → 違反量 \hat(θ) - L = 1.976e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.679611, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [12, 19]（r = 2）。上界 α − βᵀŷ = 0.702160
# ➤ 📐 評価：L(x̂,ŷ) = 0.546163 → 違反量 \hat(θ) - L = 1.334e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.610107, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 19]（r = 2）。上界 α − βᵀŷ = 0.585210
# ➤ 📐 評価：L(x̂,ŷ) = 0.289226 → 違反量 \hat(θ) - L = 3.209e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.587248, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 18]（r = 2）。上界 α − βᵀŷ = 0.696756
# ➤ 📐 評価：L(x̂,ŷ) = 0.474190 → 違反量 \hat(θ) - L = 1.131e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.566574, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 10]（r = 2）。上界 α − βᵀŷ = 0.737484
# ➤ 📐 評価：L(x̂,ŷ) = 0.566574 → 違反量 \hat(θ) - L = -3.466e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.72s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.566574 / 選択サイト [18, 19]
# ➤ 🧷 反復 9 回・追加カット 16 本・合計時間 0.72s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ...
# ➤ 🧮 ラウンド 12: master 解 → \hat(θ) = 0.516415, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 29]（r = 2）。上界 α − βᵀŷ = 0.696444
# ➤ 📐 評価：L(x̂,ŷ) = 0.516415 → 違反量 \hat(θ) - L = 1.660e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 1.24s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.516415 / 選択サイト [5, 23]
# ➤ 🧷 反復 12 回・追加カット 22 本・合計時間 1.24s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 30, 需要点 I = 30, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 27]（r = 2）。上界 α − βᵀŷ = 0.675686
# ➤ 📐 評価：L(x̂,ŷ) = 0.449415 → 違反量 \hat(θ) - L = 5.506e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [25, 26]（r = 2）。上界 α − βᵀŷ = 0.700826
# ➤ 📐 評価：L(x̂,ŷ) = 0.428377 → 違反量 \hat(θ) - L = 5.716e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.725023, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [25, 27]（r = 2）。上界 α − βᵀŷ = 0.736060
# ➤ 📐 評価：L(x̂,ŷ) = 0.525068 → 違反量 \hat(θ) - L = 2.000e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.725023, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 25]（r = 2）。上界 α − βᵀŷ = 0.726041
# ➤ 📐 評価：L(x̂,ŷ) = 0.491097 → 違反量 \hat(θ) - L = 2.339e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.704161, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [26, 27]（r = 2）。上界 α − βᵀŷ = 0.716273
# ➤ 📐 評価：L(x̂,ŷ) = 0.488416 → 違反量 \hat(θ) - L = 2.157e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.699828, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 26]（r = 2）。上界 α − βᵀŷ = 0.726439
# ➤ 📐 評価：L(x̂,ŷ) = 0.469365 → 違反量 \hat(θ) - L = 2.305e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.681351, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 27]（r = 2）。上界 α − βᵀŷ = 0.726814
# ➤ 📐 評価：L(x̂,ŷ) = 0.571623 → 違反量 \hat(θ) - L = 1.097e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.596277, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [26, 27]（r = 2）。上界 α − βᵀŷ = 0.708504
# ➤ 📐 評価：L(x̂,ŷ) = 0.505614 → 違反量 \hat(θ) - L = 9.066e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.571623, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [3, 27]（r = 2）。上界 α − βᵀŷ = 0.726814
# ➤ 📐 評価：L(x̂,ŷ) = 0.571623 → 違反量 \hat(θ) - L = 4.140e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.73s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.571623 / 選択サイト [25, 26]
# ➤ 🧷 反復 9 回・追加カット 16 本・合計時間 0.73s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 30, 需要点 I = 30, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [19, 28]（r = 2）。上界 α − βᵀŷ = 0.667538
# ➤ 📐 評価：L(x̂,ŷ) = 0.394871 → 違反量 \hat(θ) - L = 6.051e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 20]（r = 2）。上界 α − βᵀŷ = 0.736810
# ➤ 📐 評価：L(x̂,ŷ) = 0.492762 → 違反量 \hat(θ) - L = 5.072e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.751541, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [20, 28]（r = 2）。上界 α − βᵀŷ = 0.715357
# ➤ 📐 評価：L(x̂,ŷ) = 0.483030 → 違反量 \hat(θ) - L = 2.685e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.751541, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [20, 23]（r = 2）。上界 α − βᵀŷ = 0.731416
# ➤ 📐 評価：L(x̂,ŷ) = 0.582869 → 違反量 \hat(θ) - L = 1.687e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.741221, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 18]（r = 2）。上界 α − βᵀŷ = 0.732966
# ➤ 📐 評価：L(x̂,ŷ) = 0.524090 → 違反量 \hat(θ) - L = 2.171e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.705521, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [2, 28]（r = 2）。上界 α − βᵀŷ = 0.689708
# ➤ 📐 評価：L(x̂,ŷ) = 0.477482 → 違反量 \hat(θ) - L = 2.280e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.679406, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [18, 28]（r = 2）。上界 α − βᵀŷ = 0.698418
# ➤ 📐 評価：L(x̂,ŷ) = 0.523349 → 違反量 \hat(θ) - L = 1.561e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.582869, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [20, 23]（r = 2）。上界 α − βᵀŷ = 0.731416
# ➤ 📐 評価：L(x̂,ŷ) = 0.582869 → 違反量 \hat(θ) - L = -1.782e-09
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 0.56s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.582869 / 選択サイト [2, 28]
# ➤ 🧷 反復 8 回・追加カット 14 本・合計時間 0.56s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 30, 需要点 I = 30, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.670779
# ➤ 📐 評価：L(x̂,ŷ) = 0.359269 → 違反量 \hat(θ) - L = 6.407e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 23]（r = 2）。上界 α − βᵀŷ = 0.748050
# ➤ 📐 評価：L(x̂,ŷ) = 0.511962 → 違反量 \hat(θ) - L = 4.880e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.757964, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 11]（r = 2）。上界 α − βᵀŷ = 0.748283
# ➤ 📐 評価：L(x̂,ŷ) = 0.500496 → 違反量 \hat(θ) - L = 2.575e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.757964, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [1, 25]（r = 2）。上界 α − βᵀŷ = 0.745494
# ➤ 📐 評価：L(x̂,ŷ) = 0.503470 → 違反量 \hat(θ) - L = 2.545e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.745506, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [23, 25]（r = 2）。上界 α − βᵀŷ = 0.741498
# ➤ 📐 評価：L(x̂,ŷ) = 0.499504 → 違反量 \hat(θ) - L = 2.460e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.742532, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 23]（r = 2）。上界 α − βᵀŷ = 0.744648
# ➤ 📐 評価：L(x̂,ŷ) = 0.496530 → 違反量 \hat(θ) - L = 2.460e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.658036, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.678929
# ➤ 📐 評価：L(x̂,ŷ) = 0.411088 → 違反量 \hat(θ) - L = 2.469e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.616475, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.687016
# ➤ 📐 評価：L(x̂,ŷ) = 0.483144 → 違反量 \hat(θ) - L = 1.333e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.591779, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [23, 25]（r = 2）。上界 α − βᵀŷ = 0.706540
# ➤ 📐 評価：L(x̂,ŷ) = 0.466172 → 違反量 \hat(θ) - L = 1.256e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.581084, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 23]（r = 2）。上界 α − βᵀŷ = 0.719759
# ➤ 📐 評価：L(x̂,ŷ) = 0.464263 → 違反量 \hat(θ) - L = 1.168e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.571086, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.695972
# ➤ 📐 評価：L(x̂,ŷ) = 0.461964 → 違反量 \hat(θ) - L = 1.091e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 12: master 解 → \hat(θ) = 0.547013, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.724439
# ➤ 📐 評価：L(x̂,ŷ) = 0.488038 → 違反量 \hat(θ) - L = 5.898e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 13: master 解 → \hat(θ) = 0.541568, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.721768
# ➤ 📐 評価：L(x̂,ŷ) = 0.513053 → 違反量 \hat(θ) - L = 2.851e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 14: master 解 → \hat(θ) = 0.540416, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 23]（r = 2）。上界 α − βᵀŷ = 0.717106
# ➤ 📐 評価：L(x̂,ŷ) = 0.460798 → 違反量 \hat(θ) - L = 7.962e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 15: master 解 → \hat(θ) = 0.536249, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [23, 25]（r = 2）。上界 α − βᵀŷ = 0.704527
# ➤ 📐 評価：L(x̂,ŷ) = 0.442035 → 違反量 \hat(θ) - L = 9.421e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 16: master 解 → \hat(θ) = 0.523435, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.715135
# ➤ 📐 評価：L(x̂,ŷ) = 0.506254 → 違反量 \hat(θ) - L = 1.718e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 17: master 解 → \hat(θ) = 0.523359, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.713413
# ➤ 📐 評価：L(x̂,ŷ) = 0.503977 → 違反量 \hat(θ) - L = 1.938e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 18: master 解 → \hat(θ) = 0.519004, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.704897
# ➤ 📐 評価：L(x̂,ŷ) = 0.503290 → 違反量 \hat(θ) - L = 1.571e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 19: master 解 → \hat(θ) = 0.517183, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.718839
# ➤ 📐 評価：L(x̂,ŷ) = 0.515114 → 違反量 \hat(θ) - L = 2.068e-03
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 20: master 解 → \hat(θ) = 0.516304, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [23, 25]（r = 2）。上界 α − βᵀŷ = 0.725471
# ➤ 📐 評価：L(x̂,ŷ) = 0.492355 → 違反量 \hat(θ) - L = 2.395e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 21: master 解 → \hat(θ) = 0.515114, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [11, 25]（r = 2）。上界 α − βᵀŷ = 0.718839
# ➤ 📐 評価：L(x̂,ŷ) = 0.515114 → 違反量 \hat(θ) - L = 4.943e-10
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 3.57s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.515114 / 選択サイト [1, 26]
# ➤ 🧷 反復 21 回・追加カット 40 本・合計時間 3.57s
# ════════════════════════════════════════════════════════════════════════════════
# 🚀 S-CFLP を解きます（DCG + Bulge/Submodular カット）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ 候補地 J = 30, 需要点 I = 30, p = 2, r = 2
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 1: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [23, 29]（r = 2）。上界 α − βᵀŷ = 0.688667
# ➤ 📐 評価：L(x̂,ŷ) = 0.492918 → 違反量 \hat(θ) - L = 5.071e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 2: master 解 → \hat(θ) = 1.000000, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 21]（r = 2）。上界 α − βᵀŷ = 0.709223
# ➤ 📐 評価：L(x̂,ŷ) = 0.472548 → 違反量 \hat(θ) - L = 5.275e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 3: master 解 → \hat(θ) = 0.756676, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 21]（r = 2）。上界 α − βᵀŷ = 0.731809
# ➤ 📐 評価：L(x̂,ŷ) = 0.486854 → 違反量 \hat(θ) - L = 2.698e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 4: master 解 → \hat(θ) = 0.715872, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 29]（r = 2）。上界 α − βᵀŷ = 0.701728
# ➤ 📐 評価：L(x̂,ŷ) = 0.455512 → 違反量 \hat(θ) - L = 2.604e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 5: master 解 → \hat(θ) = 0.713016, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 10]（r = 2）。上界 α − βᵀŷ = 0.719508
# ➤ 📐 評価：L(x̂,ŷ) = 0.463094 → 違反量 \hat(θ) - L = 2.499e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 6: master 解 → \hat(θ) = 0.708776, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 29]（r = 2）。上界 α − βᵀŷ = 0.662537
# ➤ 📐 評価：L(x̂,ŷ) = 0.466638 → 違反量 \hat(θ) - L = 2.421e-01
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 7: master 解 → \hat(θ) = 0.615914, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [21, 29]（r = 2）。上界 α − βᵀŷ = 0.713425
# ➤ 📐 評価：L(x̂,ŷ) = 0.536906 → 違反量 \hat(θ) - L = 7.901e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 8: master 解 → \hat(θ) = 0.581508, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 21]（r = 2）。上界 α − βᵀŷ = 0.685224
# ➤ 📐 評価：L(x̂,ŷ) = 0.492330 → 違反量 \hat(θ) - L = 8.918e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 9: master 解 → \hat(θ) = 0.567022, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 29]（r = 2）。上界 α − βᵀŷ = 0.707553
# ➤ 📐 評価：L(x̂,ŷ) = 0.513146 → 違反量 \hat(θ) - L = 5.388e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 10: master 解 → \hat(θ) = 0.564406, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [7, 29]（r = 2）。上界 α − βᵀŷ = 0.725371
# ➤ 📐 評価：L(x̂,ŷ) = 0.476084 → 違反量 \hat(θ) - L = 8.832e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 11: master 解 → \hat(θ) = 0.561821, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [21, 29]（r = 2）。上界 α − βᵀŷ = 0.685074
# ➤ 📐 評価：L(x̂,ŷ) = 0.498999 → 違反量 \hat(θ) - L = 6.282e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 12: master 解 → \hat(θ) = 0.550822, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [10, 21]（r = 2）。上界 α − βᵀŷ = 0.712958
# ➤ 📐 評価：L(x̂,ŷ) = 0.523916 → 違反量 \hat(θ) - L = 2.691e-02
# ✂️  カット追加: BULGE + SUBMOD
# ────────────────────────────────────────────────────────────────────────────────
# ➤ 🧮 ラウンド 13: master 解 → \hat(θ) = 0.546434, |x| = 2/2（整数）
# ➤ 🔎 分離：ŷ は [23, 29]（r = 2）。上界 α − βᵀŷ = 0.702695
# ➤ 📐 評価：L(x̂,ŷ) = 0.546688 → 違反量 \hat(θ) - L = -2.549e-04
# ✅ 違反なし。現在の Y-closure に対して最適です。
# 🏁 求解完了（経過 1.51s）
# ════════════════════════════════════════════════════════════════════════════════
# ➤ ✨ 目的値 θ = 0.546434 / 選択サイト [10, 14]
# ➤ 🧷 反復 13 回・追加カット 24 本・合計時間 1.51s
# 保存完了: scflp_results_avg.csv
